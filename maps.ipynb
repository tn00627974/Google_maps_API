# %%
# 安裝必要的套件
# !pip install -U googlemaps

# 輸入你的Google Maps API金鑰
api_key = "你的 API 金鑰"

# 使用googlemaps套件建立API客戶端
import googlemaps
gmaps = googlemaps.Client(key=api_key)
print('ok')
# Out:
# ok

# %%
import pandas as pd
import time

# 定義一個函數來獲取附近的飲料店
def get_nearby_clinics(api_key, location, radius, keyword):
    gmaps = googlemaps.Client(key=api_key)
    clinics = []

    clinics_result = gmaps.places_nearby(
        location=location, #座標位置
        radius=radius, # 距離
        keyword=keyword # 收尋名稱
    )

    for clinic in clinics_result['results']:
        name = clinic['name']
        address = clinic['vicinity']
        rating = clinic.get('rating', 'N/A')
        clinics.append([name, address, rating])

    return clinics

# %%
# 輸入您的位置坐標 (經度和緯度)
location = "25.04503296953085, 121.57437042898609"
radius = 500  # 5公里範圍
keyword = "飲料"  # 您可以根據需求更改關鍵詞

clinics_data = get_nearby_clinics(api_key, location, radius, keyword)

# 將結果轉為Pandas DataFrame
df = pd.DataFrame(clinics_data, columns=['飲料店', '地址', '評分'])

# 顯示結果表格內容
df
# Out:
#                                                  診所名稱  \
# 0                                  COMEBUY City Store
# 1       Ching Shin Fu Chuan Tea Station Taipei Yongji
# 2                                                茶果in
# 3                                              好喜堂永春店
# 4                                                秀茶邸家
# 5                                               飲爆飲料吧
# 6                                                泡泡果樹
# 7                                   A Wen Donggua Tea
# 8                                                 快可立
# 9   Ching Shin Fu Chuan Tea Station Raohe Night Ma...
# 10                                   三良品茶.pingtea原創手作
# 11                               Samro 暹羅王國奶茶俱樂部-饒河總店
# 12                          MACU Tea Songshan Station
# 13                                          清水茶香(永吉店)
# 14                                       COMEBUY_台北永春
# 15                                           武林茶信義永吉店
# 16                                 John's Tea Company
# 17                                    Guwei Black Tea
# 18                          Milksha Taipei Hulin Shop
# 19                                     福爾摩茶 FormosaTê
#
#                                                    地址   評分
# 0   No. 5號, Alley 3, Lane 165, Section 5, Zhongxia...  4.0
# 1                                    永吉路30巷73之2號73之2號  3.9
# 2                                   No. 225, Raohe St  4.9
# 3   No. 510號, Section 5 of Zhongxiao East RoadSect...  4.2
# 4   No. 2號, Alley 3, Ln 71, Section 5, Zhongxiao E Rd  4.1
# 5                                  No. 226號, Raohe St  3.7
# 6                                   No. 231, Raohe St  3.8
# 7                                  No. 208號, Raohe St  4.4
# 8                         No. 19, Lane 278, Yongji Rd  4.5
# 9                        No. 779號, Section 4, Bade Rd  3.6
# 10                                            永吉路263號  3.9
# 11                                 No. 125號, Raohe St  4.6
# 12                                 Songshan Rd, 11號B1  3.2
# 13              No. 2號, Alley 157, Lane 30, Yongji Rd  3.8
# 14       No. 64號, Lane 423, Section 5, Zhongxiao E Rd  4.5
# 15    Alley 3, Ln 71, Section 5, Zhongxiao E Rd, 1號1樓  4.4
# 16                                         永吉路30巷123號  4.2
# 17                     No. 60號之2, Lane 278, Yongji Rd  4.6
# 18                                 No. 125號, Hulin St  3.2
# 19               Alley 101, Lane 30, Yongji Rd, 10號1樓  4.2

# %%
from google.colab import files

# # 儲存結果為CSV檔案
df.to_csv('clinics.csv', index=False)

# 下載CSV檔案到本地計算機
files.download('clinics.csv')
